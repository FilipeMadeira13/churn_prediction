# %% [markdown]
# ## Testando o modelo

# %%
new_data = {
    "gender": ["Male"],
    "SeniorCitizen": [1],
    "Partner": ["Yes"],
    "Dependents": ["No"],
    "tenure": [24],
    "PhoneService": ["Yes"],
    "MultipleLines": ["No"],
    "InternetService": ["Fiber optic"],
    "OnlineSecurity": ["Yes"],
    "OnlineBackup": ["Yes"],
    "DeviceProtection": ["No"],
    "TechSupport": ["Yes"],
    "StreamingTV": ["Yes"],
    "StreamingMovies": ["Yes"],
    "Contract": ["One year"],
    "PaperlessBilling": ["Yes"],
    "PaymentMethod": ["Bank transfer (automatic)"],
    "MonthlyCharges": [75.50],
    "TotalCharges": [1812.00]
}

# %%
import pandas as pd

# %%
new_data = pd.DataFrame(new_data)

# %%
new_data
# Out:
#   gender  SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 0   Male              1     Yes         No      24          Yes            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0     Fiber optic            Yes          Yes               No         Yes
#
#   StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 0         Yes             Yes  One year              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0  Bank transfer (automatic)            75.5        1812.0

# %%
one_hot_model = pd.read_pickle('../models/modelo_onehot.pkl')
tree_model = pd.read_pickle('../models/modelo_arvore.pkl')

# %%
new_data = one_hot_model.transform(new_data)

# %%
tree_model.predict(new_data)
# Out:
# array([0])
